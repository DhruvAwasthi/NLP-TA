# %% [markdown]
# # Query the YouTube video transcripts, returning timestamps as sources

# %%
# First set runtime to GPU

# %%
# !pip install pytube # For audio downloading from youtube
# !pip install chromadb

# %%
pip install git+https://github.com/openai/whisper.git -q # Whisper from OpenAI transcription model

# %%
import whisper
import pytube

# %%
url = "https://www.youtube.com/watch?v=XPmEJFKVOuI&ab_channel=TheAIGRID"
video = pytube.YouTube(url)

# %%
audio_stream = video.streams.filter(only_audio=True).first()
audio_stream.download(output_path='.', filename='tmp.mp3')

# %%
model = whisper.load_model("base")

# %%
transcription = model.transcribe('./tmp.mp3')

# %%
res = transcription['segments']

# %%
print(res)
# Out:
# [{'id': 0, 'seek': 0, 'start': 0.0, 'end': 5.5200000000000005, 'text': ' Sam Altman recently had an interview at Howard University where he actually spoke about a variety', 'tokens': [50364, 4832, 15992, 1601, 3938, 632, 364, 4049, 412, 17626, 3535, 689, 415, 767, 7179, 466, 257, 5673, 50640], 'temperature': 0.0, 'avg_logprob': -0.1818267822265625, 'compression_ratio': 1.6750902527075813, 'no_speech_prob': 0.038991112262010574}, {'id': 1, 'seek': 0, 'start': 5.5200000000000005, 'end': 10.56, 'text': ' of interesting topics. There was a lot he discussed that actually gives us an insight to things', 'tokens': [50640, 295, 1880, 8378, 13, 821, 390, 257, 688, 415, 7152, 300, 767, 2709, 505, 364, 11269, 281, 721, 50892], 'temperature': 0.0, 'avg_logprob': -0.1818267822265625, 'compression_ratio': 1.6750902527075813, 'no_speech_prob': 0.038991112262010574}, {'id': 2, 'seek': 0, 'start': 10.56, 'end': 15.92, 'text': ' like education, the role of AI in the future, and of course artificial general intelligence,', 'tokens': [50892, 411, 3309, 11, 264, 3090, 295, 7318, 294, 264, 2027, 11, 293, 295, 1164, 11677, 2674, 7599, 11, 51160], 'temperature': 0.0, 'avg_logprob': -0.1818267822265625, 'compression_ratio': 1.6750902527075813, 'no_speech_prob': 0.038991112262010574}, {'id': 3, 'seek': 0, 'start': 15.92, 'end': 20.32, 'text': " which kind of gives us a gauge on where he's at in terms of what he's thinking. Now,", 'tokens': [51160, 597, 733, 295, 2709, 505, 257, 17924, 322, 689, 415, 311, 412, 294, 2115, 295, 437, 415, 311, 1953, 13, 823, 11, 51380], 'temperature': 0.0, 'avg_logprob': -0.1818267822265625, 'compression_ratio': 1.6750902527075813, 'no_speech_prob': 0.038991112262010574}, {'id': 4, 'seek': 0, 'start': 20.32, 'end': 25.12, 'text': ' the initial interview was actually done back in January, but it was only just release, which', 'tokens': [51380, 264, 5883, 4049, 390, 767, 1096, 646, 294, 7061, 11, 457, 309, 390, 787, 445, 4374, 11, 597, 51620], 'temperature': 0.0, 'avg_logprob': -0.1818267822265625, 'compression_ratio': 1.6750902527075813, 'no_speech_prob': 0.038991112262010574}, {'id': 5, 'seek': 2512, 'start': 25.12, 'end': 29.6, 'text': " means that this interview is from literally four months ago. So that's of course something to", 'tokens': [50364, 1355, 300, 341, 4049, 307, 490, 3736, 1451, 2493, 2057, 13, 407, 300, 311, 295, 1164, 746, 281, 50588], 'temperature': 0.0, 'avg_logprob': -0.09248958934437145, 'compression_ratio': 1.693661971830986, 'no_speech_prob': 0.01539755892008543}, {'id': 6, 'seek': 2512, 'start': 29.6, 'end': 34.32, 'text': " keep in mind. But nevertheless, let's take a look at the first section where Sam Altman actually", 'tokens': [50588, 1066, 294, 1575, 13, 583, 26924, 11, 718, 311, 747, 257, 574, 412, 264, 700, 3541, 689, 4832, 15992, 1601, 767, 50824], 'temperature': 0.0, 'avg_logprob': -0.09248958934437145, 'compression_ratio': 1.693661971830986, 'no_speech_prob': 0.01539755892008543}, {'id': 7, 'seek': 2512, 'start': 34.32, 'end': 40.8, 'text': ' gives his opinion on what will be the most important skill for people to learn in the future.', 'tokens': [50824, 2709, 702, 4800, 322, 437, 486, 312, 264, 881, 1021, 5389, 337, 561, 281, 1466, 294, 264, 2027, 13, 51148], 'temperature': 0.0, 'avg_logprob': -0.09248958934437145, 'compression_ratio': 1.693661971830986, 'no_speech_prob': 0.01539755892008543}, {'id': 8, 'seek': 2512, 'start': 40.8, 'end': 47.040000000000006, 'text': ' Strong agree with that. I think critical thinking, creativity, the ability to figure out what other', 'tokens': [51148, 22792, 3986, 365, 300, 13, 286, 519, 4924, 1953, 11, 12915, 11, 264, 3485, 281, 2573, 484, 437, 661, 51460], 'temperature': 0.0, 'avg_logprob': -0.09248958934437145, 'compression_ratio': 1.693661971830986, 'no_speech_prob': 0.01539755892008543}, {'id': 9, 'seek': 2512, 'start': 47.040000000000006, 'end': 53.760000000000005, 'text': " people want, the ability to have new ideas, that in some sense that that' ...

# %%
from datetime import datetime

def store_segments(segments):
  texts = []
  start_times = []

  for segment in segments:
    text = segment['text']
    start = segment['start']

    # Convert the starting time to a datetime object
    start_datetime = datetime.fromtimestamp(start)

    # Format the starting time as a string in the format "00:00:00"
    formatted_start_time = start_datetime.strftime('%H:%M:%S')

    texts.append("".join(text))
    start_times.append(formatted_start_time)

  return texts, start_times

# %%
store_segments(res)

# %%
texts, start_times = store_segments(res)

# %%
print(texts,start_times)

# %%
# !pip install langchain
# Out:
# Installing collected packages: packaging, mypy-extensions, jsonpointer, typing-inspect, marshmallow, jsonpatch, langsmith, dataclasses-json, langchain-core, langchain-text-splitters, langchain-community, langchain
#   Attempting uninstall: packaging
#     Found existing installation: packaging 24.0
#     Uninstalling packaging-24.0:
#       Successfully uninstalled packaging-24.0
# Successfully installed dataclasses-json-0.6.4 jsonpatch-1.33 jsonpointer-2.4 langchain-0.1.16 langchain-community-0.0.33 langchain-core-0.1.43 langchain-text-splitters-0.0.1 langsmith-0.1.48 marshmallow-3.21.1 mypy-extensions-1.0.0 packaging-23.2 typing-inspect-0.9.0

# %%
# !pip install openai
# Out:
# Installing collected packages: httpcore, httpx, openai
# Successfully installed httpcore-1.0.5 httpx-0.27.0 openai-1.19.0

# %%
from langchain.embeddings.openai import OpenAIEmbeddings
from langchain.text_splitter import CharacterTextSplitter
from langchain import OpenAI
import openai
from langchain.vectorstores import Chroma

# %% [markdown]
# ***Dont forget to put open ai key***

# %%
OPENAI_API_KEY = ""

# %%
from langchain.docstore.document import Document

text_splitter = CharacterTextSplitter(chunk_size=1500, separator="\n")
docs = []
metadatas = []
for i, d in enumerate(texts):
    splits = text_splitter.split_text(d)
    doc = Document(
          page_content=splits[0],
          metadata={"source": start_times[i]}
      )
    docs.append(doc)
embeddings = OpenAIEmbeddings(api_key=OPENAI_API_KEY)

# %%
print((docs))
# Out:
# [Document(page_content='Sam Altman recently had an interview at Howard University where he actually spoke about a variety', metadata={'source': '00:00:00'}), Document(page_content='of interesting topics. There was a lot he discussed that actually gives us an insight to things', metadata={'source': '00:00:05'}), Document(page_content='like education, the role of AI in the future, and of course artificial general intelligence,', metadata={'source': '00:00:10'}), Document(page_content="which kind of gives us a gauge on where he's at in terms of what he's thinking. Now,", metadata={'source': '00:00:15'}), Document(page_content='the initial interview was actually done back in January, but it was only just release, which', metadata={'source': '00:00:20'}), Document(page_content="means that this interview is from literally four months ago. So that's of course something to", metadata={'source': '00:00:25'}), Document(page_content="keep in mind. But nevertheless, let's take a look at the first section where Sam Altman actually", metadata={'source': '00:00:29'}), Document(page_content='gives his opinion on what will be the most important skill for people to learn in the future.', metadata={'source': '00:00:34'}), Document(page_content='Strong agree with that. I think critical thinking, creativity, the ability to figure out what other', metadata={'source': '00:00:40'}), Document(page_content="people want, the ability to have new ideas, that in some sense that that'll be the most valuable", metadata={'source': '00:00:47'}), Document(page_content='skill of the future. If you think of a world where every one of us has a whole company worth', metadata={'source': '00:00:53'}), Document(page_content='of AI assistants that are doing tasks for us to help us express our vision and make things for', metadata={'source': '00:01:00'}), Document(page_content='other people and make these new things in the world, the most important thing then will be', metadata={'source': '00:01:07'}), Document(page_content='the quality of the ideas, the curation of the ideas, because AI can generate lots of great ideas,', metadata={'source': '00:01:13'}), Document(page_content='but still need a human there to say this is the thing other people want. And also, humans,', metadata={'source': '00:01:19'}), Document(page_content='I think really care about the human behind something. So when I read a book that I really love,', metadata={'source': '00:01:24'}), Document(page_content='the first thing I want to do is go read about that author. And if an AI wrote that book,', metadata={'source': '00:01:29'}), Document(page_content="I think I'll somehow connect to it much less. Same thing when I look at a great piece of art,", metadata={'source': '00:01:34'}), Document(page_content="or if I am using some company's product, I want to know about the people that created that.", metadata={'source': '00:01:38'}), Document(page_content='So I think in both directions of humans knowing what other humans want,', metadata={'source': '00:01:42'}), Document(page_content="and also humans caring about the humans behind something, this will be, that'll be a super", metadata={'source': '00:01:46'}), Document(page_content='important skill. And so I think learning that ability to create new ideas, choose ideas from', metadata={'source': '00:01:53'}), Document(page_content="more than many options presented by an AI, that'll be very valuable. I agree with you, the tools", metadata={'source': '00:02:00'}), Document(page_content='will change, but I also think familiarity with the tools of today and this new way of using computers', metadata={'source': '00:02:07'}), Document(page_content="is really important. And that'll be important for everyone, not just the tool builders, but", metadata={'source': '00:02:15'}), Document(page_content="every but like in the same way that if you can't use a mobile phone, you're kind of at a huge", metadata={'source': '00:02:18'}), Document(page_content="disadvantage, b ...

# %%
vectorstore = Chroma.from_documents(docs, embeddings)

# %%
vectorstore.similarity_search("agi")

# %%
from langchain.chains import VectorDBQAWithSourcesChain

# %%
chain = VectorDBQAWithSourcesChain.from_llm(llm=OpenAI(temperature=0, api_key=OPENAI_API_KEY), vectorstore=vectorstore)

# %%
result = chain.invoke({"question": "what is agi and when will it be achieved?"})
# result = chain.invoke("what is agi and when will it be achieved?")

# %%
print(f"Answer: {result['answer']}  Sources: {result['sources']}")
# Out:
# Answer:  AGI stands for Artificial General Intelligence and it is a type of artificial intelligence that is capable of performing any intellectual task that a human being can. It is often seen as the ultimate goal of AI research. As for when it will be achieved, it is difficult to say for certain. Some experts believe it could be achieved by the end of this decade, while others believe it may take much longer.
#   Sources: 00:24:32, 00:20:57, 00:04:01, 00:23:10
